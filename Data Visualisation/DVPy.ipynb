# %%
#String Formatting in python

x = 'string'
print("This is a "+x) #Doesnt give space #String Concat
print("This is a", x) #Gives space
print("This is a {}".format(x))
print(f"This is also a {x}")
# Out:
# This is a string
# This is a string
# This is a string
# This is also a string

# %% [markdown]
# ## Python Data Structures

# %% [markdown]
#  ## Python Data Structures
#
# _______________________________________________________________________________________________________________________________________________________
# ![image.png](attachment:4bdf6dbe-42d1-4c0c-a0ee-448f829aa6fa.png)
# _______________________________________________________________________________________________________________________________________________________
#
# The built in, primitive data structures in Python are:
# 1. List [ ]
# 2. Tuple ( )
# 3. Dictionary { : }
# 4. Set set( )
#
# Mutability: The ability of an object to be changed, or modified after its creation. Examples are lists, dictionaries and sets.
#
# Immutable structure examples are integers, tuples.

# %% [markdown]
# #### List Operations
# append - add element to the end of the list
#
# extend - add element to the end of the list*
#
# insert - add element to a specific position within the list, takes the parameters of \<index> and \<data>
#
# ##### *Difference between Append and Extend:
# If you append a list to another list, the method will add the list to the primary list as a single element. If you extend the primary list, then every element of the new list will be unpacked and added individually to the primary list.

# %% [markdown]
# #### Dictionary Operations
# Dictionary contains Key Value pair data, in which each unique key is assigned some value, stores within pairs separated by semi colon.
# > eg.  {'Name' : 'Ghana', 'Age' : 20}

# %% [markdown]
# You can pass integer, float, bool, etc. as well as lists, tuples, dictionarises as values for each key!
#
# ##### Specific Access of Dictionary Elements:
# mydict.items() // Returns all k v pairs
#
# mydict.keys() // Returns an array of keys
#
# mydict.values() // Returns an array of values
#
# mydict.get(key) // Returns the value for a given key as a parameter

# %% [markdown]
# #### Declaring Dictionary using tuple
# eg.
# > tuple = (Name = 'Ghana', Age = 20, Branch = 'AI')
# >
# > dict(tuple) will form a dictionary with respective key value pair!

# %%
my_dict = dict(tuple)

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________

# %%
#Utility Functions in Python
print(type(True)) #Returns the datatype of input parameter
print(len('Hello')) #Gives the length of the input parameter
print(range(0, 10, 2)) #Gives a series of numbers with start point, upto but not including endpoint and interval //Supports negative Indexing
# Out:
# <class 'bool'>
# 5
# range(0, 10, 2)

# %%
mylist = [2, 3, 6, 1, 2, 7, 9]
mylist.sort()
print(mylist) #Sorting Function for Arrays
# Out:
# [1, 2, 2, 3, 6, 7, 9]

# %% [markdown]
# ## Iteration (for and while) and Iteration Control

# %%
for i in range(0, 10, 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in range(10, 0, -2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
choice = "Y"
while(choice == "Y" or choice == "y"):
    choice = input("'y' to loop again? :-")
# Out:
# 'y' to loop again? :- y
# 'y' to loop again? :- y
# 'y' to loop again? :- Y
# 'y' to loop again? :- n

# %%
#Iteration Control: Break and Continue

for i in range(10):
    if(i == 5):
        print("Skipping 5...")
        continue
    elif i == 7:
        print("7 Occured, Exiting Loop...")
        break
    else:
        print(i)
    print("--------------Iteration Completed----------------")
# Out:
# 0
# --------------Iteration Completed----------------
# 1
# --------------Iteration Completed----------------
# 2
# --------------Iteration Completed----------------
# 3
# --------------Iteration Completed----------------
# 4
# --------------Iteration Completed----------------
# Skipping 5...
# 6
# --------------Iteration Completed----------------
# 7 Occured, Exiting Loop...

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Functions in Python

# %%
def myfunc():
    print("Hello World")
    return 0

# %%
print(myfunc())
# Out:
# Hello World
# 0

# %%
def main():
    print("This is the main function")

#Standard Syntax for implementing a main function like in c++, in which we can call other defined functions.
#This provides the code some better structure

if __name__ == '__main__':
    main()
# Out:
# This is the main function

# %% [markdown]
# We are able to pass parameters to a function, and declaring it without parameters is possible.
# Functions may also return some object, but it is not necessary

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________b

# %% [markdown]
# ## File Handling with python

# %% [markdown]
# Reading a file, and performing file operations using python
#
#
# IMPORTANT RESOURCE:
# https://www.linkedin.com/pulse/file-handling-python-360-digitmg
#
# ### File Operation Modes:
#
# 1. Read Mode 'r': The read mode is denoted by the character 'r', and it's used when you want to open a file for reading its contents.We cannot modify the file using this mode.
#
# 2. Write Mode 'w': This mode is used to write data to a file. If files do not exist,it will get created. If it already exists, contents will be overwritten. If you want to append data to the existing file content, you can use the 'a' mode instead.
#
# 3. Append Mode 'a’: This mode is used to append data to an existing file.File will be created if not present earlier. The new data will be added to the end of the existing file content, without overwriting it.
#
# 4. Binary Mode 'b’:Binary files like images,videos,audios can be handled here. For example, 'rb' is used to read a binary file, and 'wb' is used to write to a binary file.
#
# 5. Exclusive Creation Mode 'x': This mode is used to create a new file, but it raises a FileExistsError if the file already exists.
#
# 6. Update Mode '+': This mode is used to open a file for both reading and writing. It is added to the other modes. For example, 'r+' is used to open a file for both reading and writing.

# %% [markdown]
# Note that the file path uses '/' and not '\\'
# Windows uses the backslash by default. Python uses backslash as a string formatting operator hence, we switch the slash to a frontslash!

# %% [markdown]
# ##### File Syntax
#
# Opening a File:
# >file = open(\<filenamedir>, \<mode>) //Opening a file, storing it into the object of 'file'
#
# >file.close() // Closing a File
#
# NOTE: This 'file' is used as a pointer and is used to indicate successful creation or existence of a file.
# eg.
#
# >if file:
# >
# >         print("File created Successfully!")
#
#
# file.read(\<number of characters>) // reads specified amounts of character, by default reads all contents.
#
# file.readlines() // This will generate an array of all the lines in the file, can be stored in another variable and used as an iterable.
#
# file.write()
#
#
# NOTE:
# Files that do not exist can be created only by using the opening mode of 'x', 'w', 'w+' 'a', 'a+' .  'r' and 'r+', mode will not create a newfile, but will throw an exception.
#
# If you try to open an existing file with 'x' mode, i.e. recreate the file, there will be a FileExistsError exception thrown.
#
#
#
# ##### Deleting an existing file
#
# done using the os header file.
#
# dependencies:
# > import os
#
# os.remove(\<filedir>)
#
# /RENAMING THE FILE
#
# os.rename(\<oldfilenamedir>, \<newfilenamedir>)

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Pandas, Numpy, Matplotlib and Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Note: Use the 'help()' Method for using documentation for syntax based queries

# %% [markdown]
# #### Refer pandas.ipynb for pandas use
#
# #### Refer matplotlib.ipynb for matplotlib use
#
# #### Refer seaborn.ipynb for seaborn use
